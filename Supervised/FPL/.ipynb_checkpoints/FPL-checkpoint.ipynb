# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('players.csv')

# %%
df.head()
# Out:
#    id                          name  now_cost position     team  \
# 0   1         Fábio Ferreira Vieira        55      MID  Arsenal
# 1   2     Gabriel Fernando de Jesus        70      FWD  Arsenal
# 2   3  Gabriel dos Santos Magalhães        60      DEF  Arsenal
# 3   4                   Kai Havertz        80      FWD  Arsenal
# 4   5                     Karl Hein        40      GKP  Arsenal
#
#    chance_of_playing_this_round  transfers_out_event  selected_by_percent  \
# 0                          75.0                   43                  0.0
# 1                           NaN                  525                  2.4
# 2                           NaN                  992                 13.6
# 3                           NaN                 1448                 12.6
# 4                           0.0                   81                  0.1
#
#    in_dreamteam  form_rank_type  ...  goals_conceded_per_90  clean_sheets  \
# ...
